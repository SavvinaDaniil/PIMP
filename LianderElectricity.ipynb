# %%
import pandas as pd

# %%
df_liander = pd.read_excel('LianderKV01012018.xlsx')
df_liander
# Out:
#        MEETVERANTWOORDELIJKE       NETBEHEERDER  NETGEBIED  \
# 0               Liander N.V.  Liander N.V. (NW)        NaN
# 1               Liander N.V.  Liander N.V. (NW)        NaN
# 2               Liander N.V.        GAS Liander        NaN
# 3               Liander N.V.  Liander N.V. (NW)        NaN
# 4               Liander N.V.        GAS Liander        NaN
# 5               Liander N.V.  Liander N.V. (NW)        NaN
# 6                        NaN  Liander N.V. (NW)        NaN
# 7                        NaN        GAS Liander        NaN
# 8                        NaN  Liander N.V. (NW)        NaN
# 9               Liander N.V.  Liander N.V. (NW)        NaN
# 10              Liander N.V.        GAS Liander        NaN
# 11                       NaN  Liander N.V. (NW)        NaN
# 12              Liander N.V.  Liander N.V. (NW)        NaN
# 13              Liander N.V.        GAS Liander        NaN
# 14                       NaN  Liander N.V. (NW)        NaN
# ...

# %%
df_postcode = df_liander.POSTCODE_VAN.
