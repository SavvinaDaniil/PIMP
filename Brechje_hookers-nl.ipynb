# %%
from urllib.request import urlopen

hookers_nl = "https://www.hookers.nl/forum/raamprostitutie/nederland/amsterdam"

f = urlopen(hookers_nl)
myfile = f.read()

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(myfile)
text = soup.get_text()
#print(soup.prettify)
print(soup)

table = soup.find('', attrs={'class': 'stripe'})
#print(table)


#for row in table.findAll('tr'):
#    for cell in row.findAll('td'):
#        print (cell.text)
# Out:
# C:\Users\brech\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\brech\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# <!DOCTYPE html>
# <html dir="ltr" id="htmlTag" lang="nl" xml:lang="nl" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <base href="https://www.hookers.nl/"/>
# <link href="/core/packages/hookersplugin/template/favicon.ico" rel="Shortcut Icon" type="image/x-icon"/>
# <!--[if IE]>
# <link rel="stylesheet" type="text/css" href="css.php?styleid=45&amp;td=ltr&amp;sheet=css_reset.css,css_unreset.css,css_utilities.css&amp;ts=1539296726 " />
# <link rel="stylesheet" type="text/css" href="css.php?styleid=45&amp;td=ltr&amp;sheet=css_imgareaselect-animated.css,css_jquery-ui-1_11_4_custom.css,css_jquery_qtip_min.css,css_jquery_selectBox.css,css_global.css&amp;ts=1539296726 " />
# <link rel="stylesheet" type="text/css" href="css.php?styleid=45&amp;td=ltr&amp;sheet=css_fonts.css,css_b_link.css,css_b_layout.css,css_b_button.css,css_b_button_group.css&amp;ts=1539296726 " />
# <link rel="stylesheet" type="text/css" href="css.php?styleid=45&amp;td=ltr&amp;sheet=css_b_icon.css,css_b_tabbed_pane.css,css_b_form_control.css,css_b_form_input.css,css_b_form_select.css&amp;ts=1539296726 " />
# <link rel="stylesheet" type="text/css" href="css.php?styleid=45&amp;td=ltr&amp;sheet=css_b_form_textarea.css,css_b_media.css,css_b_divider.css,css_b_avatar.css,css_b_ajax_loading_indicator.css&amp;ts=1539296726 " />
# <link rel="stylesheet" type="text/css" href="css.php?styleid=45&amp;td=ltr&amp;sheet=css_b_topicpreview.css,css_responsive.css,css_b_vbscroller.css,css_b_theme_selector.css,css_b_top_background.css&amp;ts=1539296726 " />
# <link rel="stylesheet" type="text/css" href="css.php?styleid=45&amp;td=ltr&amp;sheet=css_b_module.css,css_b_comp_menu_horizontal.css,css_b_comp_menu_dropdown.css,css_b_comp_menu_vert.css,css_b_top_menu.css&amp;ts=1539296726 " />
# <![endif]-->
# <!--[if !IE]><!-->
# <link href="css.php?styleid=45&amp;td=ltr&amp;sheet=css_reset.css,css_unreset.css,css_utilities.css&amp;ts=1539296726 " rel="stylesheet" type="text/css"/>
# <link href="css.php?styleid=45&amp;td=ltr&amp;sheet=css_imgareaselect-animated.css,css_jquery-ui-1_11_4_custom.css,css_jquery_qtip_min.css,css_jquery_selectBox.css,css_global.css,css_fonts.css,css_b_link.css,css_b_layout.css,css_b_button.css,css_b_button_group.css,css_b_icon.css,css_b_tabbed_pane.css,css_b_form_control.css,css_b_form_input.css,css_b_form_select.css,css_b_form_textarea.css,css_b_media.css,css_b_divider.css,css_b_avatar.css,css_b_ajax_loading_indicator.css,css_b_topicpreview.css,css_responsive.css,css_b_vbscroller.css,css_b_theme_selector.css,css_b_top_background.css,css_b_module.css,css_b_comp_menu_horizontal.css,css_b_comp_menu_dropdown.css,css_b_comp_menu_vert.css,css_b_top_menu.css&amp;ts=1539296726 " rel="stylesheet" type="text/css"/>
# <!--<![endif]-->
# <script src="js/header-rollup-534.js" type="text/javascript"></script>
# <meta content="Hookers.nl" property="og:site_name"/>
# <meta content="Raamprostitutie in Amsterdam. Lees hier exclusief de recensies van dames die aan raamprostitutie doen op de Wallen, de Pijp en andere straten." property="og:description"/>
# <meta content="https://www.hookers.nl/forum/raamprostitutie/nederland/amsterdam" property="og:url"/>
# <meta content="website" property="og:type"/>
# <link href="https://www.hookers.nl/forum/raamprostitutie/nederland/amsterdam" rel="canonical"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>
#
#
# 			Raamprostitutie in Amsterdam -
#
# 		Hookers.nl
# 	</title>
# <meta content="Raamprostitutie in Amsterdam. Lees hier exclusief de recensies van dames die aan raamprostitutie doen op de Wallen, de Pijp en andere straten." name="description"/>
# <!--[if IE]>
# <link class="js-additional-css" rel="stylesheet" type="text/css" href="css.php?styleid=45&amp;td=ltr&amp;sheet=css_additional.css&amp;ts=1539296726 " />
# <![endif]-->
# <!--[if !IE]><!-->
# <link class="js-additional-css" href="css.php?styleid=45&amp;td=ltr&amp;sheet=css_additional.css&amp;ts=1539296726 " rel="stylesheet" type="text/css"/>
# <!--<![endif]-->
# <script type="text/javascript">
# 		if (location.hash) {
# 			document.write('<style type="text/css"> a.anchor { display:none;} <\/style>');
# 		}
#
# 		var uploadUrlTarget = "https://www.hookers.nl/uploader/url";
# 		var pageData = {
# 			"baseurl": "https://www.hookers.nl",
# 			"baseurl_path": "/",
# 			"baseurl_login": "https://www.hookers.nl",
# 			"baseurl_core": "https://www.hookers.nl/core",
# 			"pageid": "189",
# 			"pagetemplateid": "2",
# 			"channelid": "85",
# 			"nodeid": "85",
# 			"userid": "0",
# 			"user_startofweek": "1",
#
# 			"user_lang_pickerdateformatoverride": "d-m-Y H:i",
# 			"textDirLeft": "left",
# 			"textDirRight": "right",
# 			"textdirection": "ltr",
# 			"can_use_sitebuilder": "",
# 			"cookie_prefix": "bb",
# 			"cookie_path": "/",
# 			"cookie_domain": "",
# 			"sb_state_cookie": "bbsitebuilder_active",
# 			"inlinemod_cookie_name": "inlinemod_nodes",
#
# 				"pagenum": "1",
#
# 			"languageid": "5",
# 			"threadmarking": "2",
# 			"lastvisit": "1539686635",
# 			"phrasedate": "1537453746",
# 			"optionsdate": "1535616661",
#
# 			"current_server_datetime": "1539686635",
# 			"simpleversion": "v=534",
#
# 			"showhv_post": "1",
#
# 			"nextcron": "1539687000",
# 			"securitytoken": "guest"
# 		};
#
#
#
# 	</script>
# <script src="./core/packages/hookersplugin/template/app.js?v=10"></script>
# <link href="./core/packages/hookersplugin/template/app.css?v=10" rel="stylesheet"/>
# <link href="./core/packages/hookersplugin/fonts/font-awesome/css/font-awesome.min.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans" rel="stylesheet"/>
# <link href="https://www.hookers.nl/external?type=rss2" rel="alternate" title="Hookers.nl" type="application/rss+xml"/>
# <link href="https://www.hookers.nl/external?type=rss2&amp;nodeid=85" rel="alternate" title="Hookers.nl -- Amsterdam" type="application/rss+xml"/>
# <link href="https://www.hookers.nl/forum/raamprostitutie/nederland/amsterdam/page2" rel="next"/>
# </head>
# <!--[if gte IE 9]>
# <body id="vb-page-body" class="l-desktop page189 vb-page ie ie9 view-mode logged-out" itemscope itemtype="http://schema.org/WebPage" data-usergroupid="1" data-styleid="45>
# <![endif]-->
# <!--[if !IE]><!-->
# <body class="l-desktop page189 vb-page view-mode logged-out" data-styleid="45" data-usergroupid="1" id="vb-page-body" itemscope="" itemtype="http://schema.org/WebPage">
# <!--<![endif]-->
# <script type="text/javascript">
# 	vBulletin.Responsive.Debounce.checkBrowserSize();
# </script>
# <div class="b-top-menu__background b-top-menu__background--sitebuilder js-top-menu-sitebuilder h-hide">
# <div class="b-top-menu__container">
# <ul class="b-top-menu b-top-menu--sitebuilder js-top-menu-sitebuilder--list">
# </ul>
# </div>
# </div>
# <div class="b-top-menu__background js-top-menu-user">
# <div class="b-top-menu__container">
# <ul class="b-top-menu b-top-menu--user js-top-menu-user--list js-shrink-event-parent">
# <li class="b-top-menu__item b-top-menu__item--no-left-divider b-top-menu__item--no-right-divider username-container js-shrink-event-child">
# <div class="b-comp-menu-dropdown b-comp-menu-dropdown--headerbar js-comp-menu-dropdown b-comp-menu-dropdown--open-on-hover js-login-menu">
# <div class="b-comp-menu-dropdown__trigger js-comp-menu-dropdown__trigger b-comp-menu-dropdown__trigger--arrow b-comp-menu-dropdown__trigger--headerbar js-button" id="lnkLoginSignupMenu" tabindex="0">
# Login of Aanmelden
# </div>
# <ul class="b-comp-menu-dropdown__content js-comp-menu-dropdown__content b-comp-menu-dropdown__content--right">
# <li class="b-comp-menu-dropdown__content-item b-comp-menu-dropdown__content-item--no-hover" id="idLoginIframeContainer">
# <iframe class="js-menu__login-iframe" id="idLoginIframe" src="https://www.hookers.nl/auth/login-form"></iframe>
# </li>
# <li class="b-comp-menu-dropdown__content-item b-comp-menu-dropdown__content-item--no-hover js-external-login-providers h-clearfix h-hide-imp" id="externalLoginProviders">
# <span class="h-left h-margin-left-s h-margin-top-s">Log in met</span>
# </li>
# </ul>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="noselect h-clearfix" id="sitebuilder-wrapper">
# </div>
# <div class="main-navbar-bottom-line"></div>
# <div id="outer-wrapper">
# <div id="wrapper">
# <div class="header-edit-box axdnum_1 h-clearfix" id="header-axd">
# <div class="axd-container axd-container_header">
# <div class="admin-only">
# </div>
# <div class="axd axd_header">
# </div>
# </div>
# <div class="axd-container axd-container_header2">
# <div class="admin-only">
# </div>
# <div class="axd axd_header2">
# </div>
# </div>
# </div>
# <div class="b-top-background__header-mainnav-subnav">
# <div class="b-top-background__header-mainnav">
# <div class="noselect" id="header">
# <div class="header-cell">
# <div class="site-logo header-edit-box">
# <a href="https://www.hookers.nl/"><img alt="Logo" data-orig-src="core/packages/hookersplugin/images/logo_hookers.png" src="core/packages/hookersplugin/images/logo_hookers.png" title="Forumsoftware: vBulletin"/></a>
# </div>
# </div>
# <div class="toolbar">
# <ul class="h-right">
# </ul>
# </div>
# </div>
# <div class="h-clearfix noselect" id="channel-tabbar">
# <ul class="channel-tabbar-list h-left b-comp-menu-horizontal js-comp-menu-horizontal js-comp-menu--dropdown-on-small b-comp-menu-dropdown--inactive js-comp-menu-dropdown__content--main-menu h-hide-on-small">
# <li class="current section-item">
# <a class="h-left navbar_home" href="https://www.hookers.nl/">Forum</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class=" section-item">
# <a class="h-left navbar_social_groups" href="http://raamwijzer.nl/?utm_source=hookers&amp;utm_medium=tekstlink&amp;utm_campaign=hookersnavbar" target="_blank">Raamwijzer</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class=" section-item">
# <a class="h-left navbar_blogs" href="http://www.kinky.nl/?utm_source=hookers&amp;utm_medium=tekstlink&amp;utm_campaign=hookersnavbar" target="_blank">Seksadvertenties</a>
# <span class="channel-tabbar-divider"></span>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# <li class=" section-item">
# <a class="h-left navbar_articles" href="http://www.webcambordeel.nl/?referer=20009" target="_blank">Webcambordeel</a>
# <span class="mobile dropdown-icon"><span class="icon h-right"></span></span>
# </li>
# </ul>
# </div>
# </div>
# <div class="h-clearfix h-hide-on-small h-block" id="channel-subtabbar">
# <ul class="h-left channel-subtabbar-list js-channel-subtabbar-list">
# <li class=""><a class="navbar_newtopics" href="https://www.hookers.nl/search?searchJSON=%7B%22view%22%3A%22topic%22%2C%22unread_only%22%3A1%2C%22sort%22%3A%7B%22lastcontent%22%3A%22desc%22%7D%2C%22exclude_type%22%3A%5B%22vBForum_PrivateMessage%22%5D%7D">Nieuwe Topics</a></li>
# <li class=""><a class="navbar_todays_posts" href="https://www.hookers.nl/search?searchJSON=%7B%22last%22%3A%7B%22from%22%3A%22lastDay%22%7D%2C%22view%22%3A%22topic%22%2C%22starter_only%22%3A+1%2C%22sort%22%3A%7B%22lastcontent%22%3A%22desc%22%7D%2C%22exclude_type%22%3A%5B%22vBForum_PrivateMessage%22%5D%7D">Berichten van vandaag</a></li>
# <li class=""><a class="navbar_whos_online" href="https://www.hookers.nl/online">Wie is er online?</a></li>
# </ul>
# </div>
# </div>
# <ul class="h-clearfix" id="breadcrumbs" itemprop="breadcrumb">
# <li class="crumb ellipsis"><a class="crumb-link" href="https://www.hookers.nl/">Home</a></li>
# <li class="vb-icon separator"></li>
# <li class="crumb ellipsis"><a class="crumb-link" href="https://www.hookers.nl/forum">Forum</a></li>
# <li class="vb-icon separator"></li>
# <li class="crumb ellipsis"><a class="crumb-link" href="https://www.hookers.nl/forum/raamprostitutie">Raamprostitutie</a></li>
# <li class="vb-icon separator"></li>
# <li class="crumb ellipsis"><a class="crumb-link" href="https://www.hookers.nl/forum/raamprostitutie/nederland">Nederland</a></li>
# <li class="vb-icon separator"></li>
# <li class="crumb ellipsis">Amsterdam</li>
# </ul>
# <div id="content">
# <div id="adv-header"></div> <br/>
# <div class="canvas-layout-container js-canvas-layout-container">
# <div class="canvas-layout" data-layout-id="1" id="canvas-layout-full">
# <div class="canvas-layout-row l-row no-columns h-clearfix">
# <div class="canvas-widget-list section-2 js-sectiontype-notice h-clearfix l-col__large-12 l-col__small--full l-wide-column">
# <div class="b-module canvas-widget default-widget page-title-widget widget-no-header-buttons widget-no-border" data-widget-id="56" data-widget-instance-id="11" id="widget_11">
# <div class="widget-header h-clearfix">
# <div class="module-title h-left">
# <h1 class="main-title js-main-title hide-on-editmode h-inline-block">Raamprostitutie in Amsterdam</h1>
# </div>
# <div class="module-buttons">
# <span class="toggle-button module-button-item collapse" data-toggle-title="Expand" title="Inklappen"><span class="b-icon b-icon__toggle-collapse">Inklappen</span></span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="canvas-layout-row l-row no-columns h-clearfix">
# <div class="canvas-widget-list section-0 js-sectiontype-primary js-sectiontype-secondary h-clearfix l-col__large-12 l-col__small--full l-wide-column">
# <div class="b-module canvas-widget subchannel-widget widget-no-border widget-no-header admin-only" data-widget-id="8" data-widget-instance-id="14" id="widget_14">
# <div class="widget-content">
# <table class="forum-list-container stretch">
# <tr class="forum-list-header">
# <th class="header-forum"><span>Forums</span></th>
# <th class="header-topics"><span>Onderwerpen</span></th>
# <th class="header-posts"><span>Berichten</span></th>
# <th class="header-lastpost"><span>Laatste bericht</span></th>
# </tr>
# </table>
# <div class="conversation-empty">Geen forums gevonden.</div>
# <div class="list-footer"><a class="markchannelsread" href="#">Markeer kanalen als gelezen</a></div>
# </div>
# </div>
# <div class="b-module canvas-widget channel-content-widget forum-channel-content-widget default-widget widget-no-header-buttons widget-no-border" data-canviewtopiccontent="1" data-node-id="85" data-widget-default-tab="#topic-tab" data-widget-id="6" data-widget-instance-id="13" id="widget_13">
# <div class="widget-content">
# <div class="channel-controls h-right h-clear b-button-group h-margin-bottom-l js-movable-toolbar-button-container">
# <button class="button-stap float-left" onclick="window.location.href = pageData.baseurl + '/recensie?nodeid=' + '85'" type="button">Recensie schrijven</button>
# <div class="order-container">
# <div class="alfanav" id="customnav">
# <alphabetic :parentnode='{"parent":"26","child":"85","depth":"2","displayorder":"0","publishdate":"1499939025","nodeid":"26","userid":"1","parentid":"2","routeid":"89","title":"Raamprostitutie","urlident":"raamprostitutie","contenttypeid":"29","unpublishdate":null,"showpublished":"1","starter":"0","lastcontentid":"2017632"}' :topics='Object.values({"259":{"name":"Anna 1","city":"Amsterdam - De Wallen","street":"La Vie en Rose","number":"k8","company":null,"nodeid":"259","score":"9.0088"},"260":{"name":"Stella","city":"Wallen","street":"Oudezijds Achterburgwal","number":"68 sous rts","company":null,"nodeid":"260","score":"7.5893"},"262":{"name":"Laura (Ned)","city":"Singelgebied","street":"Korte Kolksteeg","number":"3 rts","company":null,"nodeid":"262","score":"8.4211"},"288":{"name":"Sherida","city":"Amsterdam - De Wallen","street":"Trompettersteeg","number":"1-2","company":null,"nodeid":"288","score":"6.1250"},"299":{"name":"Sandy (Filipp)","city":"Wallen","street":"Stoofsteeg","number":"4 lks","company":null,"nodeid":"299","score":"8.6087"},"324":{"name":"Mirjam (Sur)","city":"Singelgebied","street":"Oude Nieuwstraat","number":"6 bov","company":null,"nodeid":"324","score":"8.0667"},"393":{"name":"Tamara (Ned)","city":"Singelgebied","street":"Korte Korsjespoortsteeg","number":"7a","company":null,"nodeid":"393","score":"8.9048"},"432":{"name":"Marina (Oekr)","city":"Singelgebied","street":"Singel","number":"41a","company":null,"nodeid":"432","score":"8.4889"},"558":{"name":"Carmen (Lat)","city":"Amsterdam - Singelgebied","street":"Oude Nieuwstraat","number":"2 lks","company":null,"nodeid":"558","score":"6.5152"},"571":{"name":"Jennifer","city":"Wallen","street":"Stoofsteeg","number":"9 lks","company":null,"nodeid":"571","score":"9.2162"},"581":{"name":"Sara (Lat)","city":"Singelgebied","street":"Oude Nieuwstraat","number":null,"company":null,"nodeid":"581","score":"8.5000"},"603":{"name":"Claudia","city":"Singelgebied","street":"Spuistraat","number":"19 bov lks","company":null,"nodeid":"603","score":"6.8125"},"615":{"name":"Judith","city":"De Pijp","street":"Govert Flinckstraat","number":"1","company":null,"nodeid":"615","score":"8.6333"},"667":{"name":"Patricia (Dom R)  ","city":"Amsterdam - De Pijp","street":"Ruysdaelkade","number":"135 lks","company":null,"nodeid":"667","score":"8.2174"},"670":{"name":"Gloria (Claudia)","city":"De Pijp","street":"Ruysdaelkade","number":"201","company":null,"nodeid":"670","score":"8.4032"},"707":{"name":"Gloria (Albn)","city":"Wallen","street":"Trompettersteeg","number":"5-6","company":null,"nodeid":"707","score":"6.4314"},"749":{"name":"Nathalie (Lat)","city":"Singelgebied","street":"Spuistraat","number":"47 lks","company":null,"nodeid":"749","score":"7.9583"},"982":{"name":"Sylvia (Ned)","city":"Wallen","street":"Stoofsteeg","number":"4 mid","company":null,"nodeid":"982","score":"8.3793"},"984":{"name":"Sonja","city":"De Pijp","street":"Ruysdaelkade","number":"141 ben lks","company":null,"nodeid":"984","score":"8.3934"},"998":{"name":"Maris (Marisol)","city":"Singelgebied","street":"Oude Nieuwstraat","number":"4 mid","company":null,"nodeid":"998","score":"7.7609"},"1088":{"name":"Anna (Ital)","city":"Wallen","street":"Oudezijds Achterburgwal","number":"51-4","company":null,"nodeid":"1088","score":"8.3333"},"1143":{"name":"Sofia \/ Emilia (Roem)","city":"Wallen","street":"Dollebegijnensteeg","number":"7-3","company":null,"nodeid":"1143","score":"8.8043"},"1224":{"name":"Maria","city":"Wallen","street":"Oudekerksplein","number":"34 lks","company":null,"nodeid":"1224","score":"8.3662"},"1334":{"name":"Angelique","city":"Wallen","street":"Sint Annenstraat","number":"119","company":null,"nodeid":"1334","score":"8.7200"},"1351":{"name":"Kristina","city":"Amsterdam - Singelgebied","street":"Korte Kolksteeg","number":"3 lks","company":null,"nodeid":"1351","score":"8.3372"},"1381":{"name":"Eva (Tsjech)","city":"Singelgebied","street":"Oude Nieuwstraat","number":"4 mid","company":null,"nodeid":"1381 ...
# </div>
# <div id="only-for-me" style="display: none;">{"259":{"name":"Anna 1","city":"Amsterdam - De Wallen","street":"La Vie en Rose","number":"k8","company":null,"nodeid":"259","score":"9.0088"},"260":{"name":"Stella","city":"Wallen","street":"Oudezijds Achterburgwal","number":"68 sous rts","company":null,"nodeid":"260","score":"7.5893"},"262":{"name":"Laura (Ned)","city":"Singelgebied","street":"Korte Kolksteeg","number":"3 rts","company":null,"nodeid":"262","score":"8.4211"},"288":{"name":"Sherida","city":"Amsterdam - De Wallen","street":"Trompettersteeg","number":"1-2","company":null,"nodeid":"288","score":"6.1250"},"299":{"name":"Sandy (Filipp)","city":"Wallen","street":"Stoofsteeg","number":"4 lks","company":null,"nodeid":"299","score":"8.6087"},"324":{"name":"Mirjam (Sur)","city":"Singelgebied","street":"Oude Nieuwstraat","number":"6 bov","company":null,"nodeid":"324","score":"8.0667"},"393":{"name":"Tamara (Ned)","city":"Singelgebied","street":"Korte Korsjespoortsteeg","number":"7a","company":null,"nodeid":"393","score":"8.9048"},"432":{"name":"Marina (Oekr)","city":"Singelgebied","street":"Singel","number":"41a","company":null,"nodeid":"432","score":"8.4889"},"558":{"name":"Carmen (Lat)","city":"Amsterdam - Singelgebied","street":"Oude Nieuwstraat","number":"2 lks","company":null,"nodeid":"558","score":"6.5152"},"571":{"name":"Jennifer","city":"Wallen","street":"Stoofsteeg","number":"9 lks","company":null,"nodeid":"571","score":"9.2162"},"581":{"name":"Sara (Lat)","city":"Singelgebied","street":"Oude Nieuwstraat","number":null,"company":null,"nodeid":"581","score":"8.5000"},"603":{"name":"Claudia","city":"Singelgebied","street":"Spuistraat","number":"19 bov lks","company":null,"nodeid":"603","score":"6.8125"},"615":{"name":"Judith","city":"De Pijp","street":"Govert Flinckstraat","number":"1","company":null,"nodeid":"615","score":"8.6333"},"667":{"name":"Patricia (Dom R)  ","city":"Amsterdam - De Pijp","street":"Ruysdaelkade","number":"135 lks","company":null,"nodeid":"667","score":"8.2174"},"670":{"name":"Gloria (Claudia)","city":"De Pijp","street":"Ruysdaelkade","number":"201","company":null,"nodeid":"670","score":"8.4032"},"707":{"name":"Gloria (Albn)","city":"Wallen","street":"Trompettersteeg","number":"5-6","company":null,"nodeid":"707","score":"6.4314"},"749":{"name":"Nathalie (Lat)","city":"Singelgebied","street":"Spuistraat","number":"47 lks","company":null,"nodeid":"749","score":"7.9583"},"982":{"name":"Sylvia (Ned)","city":"Wallen","street":"Stoofsteeg","number":"4 mid","company":null,"nodeid":"982","score":"8.3793"},"984":{"name":"Sonja","city":"De Pijp","street":"Ruysdaelkade","number":"141 ben lks","company":null,"nodeid":"984","score":"8.3934"},"998":{"name":"Maris (Marisol)","city":"Singelgebied","street":"Oude Nieuwstraat","number":"4 mid","company":null,"nodeid":"998","score":"7.7609"},"1088":{"name":"Anna (Ital)","city":"Wallen","street":"Oudezijds Achterburgwal","number":"51-4","company":null,"nodeid":"1088","score":"8.3333"},"1143":{"name":"Sofia \/ Emilia (Roem)","city":"Wallen","street":"Dollebegijnensteeg","number":"7-3","company":null,"nodeid":"1143","score":"8.8043"},"1224":{"name":"Maria","city":"Wallen","street":"Oudekerksplein","number":"34 lks","company":null,"nodeid":"1224","score":"8.3662"},"1334":{"name":"Angelique","city":"Wallen","street":"Sint Annenstraat","number":"119","company":null,"nodeid":"1334","score":"8.7200"},"1351":{"name":"Kristina","city":"Amsterdam - Singelgebied","street":"Korte Kolksteeg","number":"3 lks","company":null,"nodeid":"1351","score":"8.3372"},"1381":{"name":"Eva (Tsjech)","city":"Singelgebied","street":"Oude Nieuwstraat","number":"4 mid","company":null,"nodeid":"1381","score":"8.7647"},"1467":{"name":"Marie (Peru)","city":"Wallen","street":"Dollebegijnensteeg","number":"111a","company":null,"nodeid":"1467","score":"6.2381"},"1786":{"name":"Melanie (Thai)","city":"Wallen","street":"Oudekennissteeg","number":"5 lks","company":null,"nodeid":"1786","score":"8.8485"},"18 ...
# </div>
# </div>
# <div class="channel-conversation-list-wrapper block widget-tabs ui-tabs h-clear">
# <a class="anchor js-module-top-anchor" id="channel-module-top"></a>
# <div class="blockhead widget-tabs-nav">
# <ul class="ui-tabs-nav b-comp-menu-horizontal js-module-tab-menu js-comp-menu-horizontal js-comp-menu--dropdown-on-xsmall b-comp-menu-dropdown--inactive" data-allow-history="1">
# <li class="ui-tabs-active">
# <a href="#topic-tab">Topics</a>
# </li>
# <li>
# <a href="#activity-stream-tab">Meest recente activiteit</a>
# </li>
# <li>
# <a href="#subscribed-tab">Mijn abonnementen</a>
# </li>
# <li>
# <a href="#media-tab">Fotos</a>
# </li>
# </ul>
# </div>
# <div class="blockbody widget-tabs-panel h-clearfix">
# <div class="h-hide" id="activity-stream-tab">
# <div class="conversation-toolbar-wrapper top h-clear hide-on-editmode scrolltofixed-floating scrolltofixed-top " data-allow-history="1">
# <div class="conversation-toolbar js-shrink-event-parent">
# <ul class="toolset-left js-shrink-event-child ">
# <!-- new conversation button -->
# <!-- /new conversation button -->
# </ul>
# <ul class="toolset-right js-shrink-event-child">
# <li class="toolbar-pagenav js-toolbar-pagenav h-hide-on-xsmall">
# <div class="toolbar-pagenav-wrapper">
# <!-- Page Nav controls -->
# <div class="pagenav-controls ">
# <form action="https://www.hookers.nl/forum/raamprostitutie/nederland/amsterdam" class="pagenav-form h-clearfix">
# <input class="defaultpage" type="hidden" value="1"/>
# <div class="pagenav h-left">
# 			Pagina <input class="js-pagenum textbox h-padding-horiz-none" name="page" type="text" value="1"/> van <span class="pagetotal">1</span>
# </div>
# <div class="horizontal-arrows h-left">
# <a class="arrow left-arrow h-disabled" rel="prev" title="Vorige pagina"><span class="vb-icon vb-icon-arrow-left"></span></a>
# <a class="arrow right-arrow h-disabled" rel="next" title="Volgende pagina"><span class="vb-icon vb-icon-arrow-right"></span></a>
# </div>
# </form>
# </div>
# </div>
# </li>
# <li class="h-hide-on-xsmall">
# <div class="toolbar-divider">
# <span class="toolbar-divider-inner"></span>
# </div>
# </li>
# <li class="toolbar-filter toolbar-filter-top">
# <div class="filter-wrapper h-clearfix js-button" tabindex="0">
# <div class="label h-left">Filter</div>
# <div class="arrow vb-icon-wrapper h-left"><span class="vb-icon vb-icon-triangle-down-wide"></span></div>
# </div>
# </li>
# </ul>
# </div>
# <form action="activity/get" class="toolbar-filter-overlay h-clearfix" method="post">
# <input name="nodeid" type="hidden" value="85"/>
# <input name="view" type="hidden" value="activity"/>
# <input name="per-page" type="hidden" value="50"/>
# <input name="pagenum" type="hidden" value="1"/>
# <input name="maxpages" type="hidden" value="50"/>
# <input name="userid" type="hidden" value="0"/>
# <input name="showChannelInfo" type="hidden" value="1"/>
# <ul class="filter-options-list">
# <li>
# <div class="filter-header">Tijd</div>
# <div class="filter-options">
# <label><input name="filter_time" type="radio" value="time_all"/><span>Alle tijden</span></label>
# <label><input name="filter_time" type="radio" value="time_today"/><span>Vandaag</span></label>
# <label><input name="filter_time" type="radio" value="time_lastweek"/><span>Afgelopen week</span></label>
# <label><input checked="checked" class="js-default-checked" name="filter_time" type="radio" value="time_lastmonth"/><span>Afgelopen maand</span></label>
# </div>
# </li>
# <li>
# <div class="filter-header">Toon</div>
# <div class="filter-options">
# <label><input checked="checked" class="js-default-checked" name="filter_show" type="radio" value="show_all"/><span>Alle</span></label>
# <label><input name="filter_show" type="radio" value="vBForum_Text"/><span>Alleen discussies</span></label>
# <label><input name="filter_show" type="radio" value="vBForum_Gallery"/><span>Alleen fotos</span></label>
# <label><input name="filter_show" type="radio" value="vBForum_Video"/><span>Alleen videos</span></label>
# <label><input name="filter_show" type="radio" value="vBForum_Link"/><span>Alleen links</span></label>
# <label><input name="filter_show" type="radio" value="vBForum_Poll"/><span>Alleen enquêtes</span></label>
# <label><input name="filter_show" type="radio" value="vBForum_Event"/><span>Events only</span></label>
# </div>
# </li>
# <li>
# <div class="filter-header">Nieuwe onderwerpen</div>
# <div class="filter-options">
# <label><input name="filter_new_topics" type="radio" value="1"/><span>Aan</span></label>
# <label><input checked="checked" class="js-default-checked" name="filter_new_topics" type="radio" value="0"/><span>Uit</span></label>
# </div>
# </li>
# <!-- end if prefixsets -->
# </ul>
# </form>
# <div class="filtered-by h-clearfix h-hide">
# <label>Gefilterd op:</label>
# <div class="filter-text-wrapper h-left">
# </div>
# <a class="clear-all h-hide" href="#">Clear All</a>
# </div>
# <div class="new-conversations-strip"><span></span> nieuwe berichten</div>
# </div>
# <div class="h-show-on-xsmall h-right h-margin-top-l js-under-toolbar-pagenav h-margin-bottom-m">
# <div class="pagenav-container h-clearfix noselect h-hide pagenav-container--no-margin">
# <div class="js-pagenav pagenav h-right js-shrink-event-parent">
# <a class="js-pagenav-button js-pagenav-prev-button b-button b-button--secondary h-hide-imp js-shrink-event-child" data-page="0" href="" tabindex="0">Vorige</a>
# <a class="js-pagenav-button js-pagenav-next-button b-button b-button--secondary h-hide-imp js-shrink-event-child" data-page="0" href="" tabindex="0">Volgende</a>
# </div>
# </div>
# </div>
# <ul class="conversation-list list-container stream-view stream-view-full-width activity-view h-clearfix h-hide">
# </ul>
# <div class="conversation-empty">Er zijn geen conversaties in dit forum.</div>
# <div class="pagenav-container h-clearfix noselect h-hide">
# <div class="js-pagenav pagenav h-right js-shrink-event-parent">
# <a class="js-pagenav-button js-pagenav-prev-button b-button b-button--secondary h-hide-imp js-shrink-event-child" data-page="0" tabindex="0">Vorige</a>
# <a class="js-pagenav-button js-pagenav-next-button b-button b-button--secondary h-hide-imp js-shrink-event-child" data-page="0" tabindex="0">Volgende</a>
# </div>
# </div>
# </div>
# <div class="h-hide" id="subscribed-tab">
# <div class="conversation-toolbar-wrapper top h-clear hide-on-editmode scrolltofixed-floating scrolltofixed-top " data-allow-history="1">
# <div class="conversation-toolbar js-shrink-event-parent">
# <ul class="toolset-right js-shrink-event-child">
# <li class="toolbar-filter toolbar-filter-top">
# <div class="filter-wrapper h-clearfix js-button" tabindex="0">
# <div class="label h-left">Filter</div>
# <div class="arrow vb-icon-wrapper h-left"><span class="vb-icon vb-icon-triangle-down-wide"></span></div>
# </div>
# </li>
# </ul>
# </div>
# <form action="profile/ApplyFollowingFilter" class="toolbar-filter-overlay h-clearfix" method="post">
# <input name="nodeid" type="hidden" value="85"/>
# <input name="view" type="hidden" value="subscribed"/>
# <input name="per-page" type="hidden" value="10"/>
# <input name="pagenum" type="hidden" value="1"/>
# <input name="maxpages" type="hidden" value="20"/>
# <input name="userid" type="hidden" value="0"/>
# <input name="showChannelInfo" type="hidden" value="0"/>
# <ul class="filter-options-list">
# <li>
# <div class="filter-header">Tijd</div>
# <div class="filter-options">
# <label><input name="filter_time" type="radio" value="time_all"/><span>Alle tijden</span></label>
# <label><input name="filter_time" type="radio" value="time_today"/><span>Vandaag</span></label>
# <label><input name="filter_time" type="radio" value="time_lastweek"/><span>Afgelopen week</span></label>
# <label><input checked="checked" class="js-default-checked" name="filter_time" type="radio" value="time_lastmonth"/><span>Afgelopen maand</span></label>
# </div>
# </li>
# <li>
# <div class="filter-header">Toon</div>
# <div class="filter-options">
# <label><input checked="checked" class="js-default-checked" name="filter_show" type="radio" value="show_all"/><span>Alle</span></label>
# <label><input name="filter_show" type="radio" value="vBForum_Text"/><span>Alleen discussies</span></label>
# <label><input name="filter_show" type="radio" value="vBForum_Gallery"/><span>Alleen fotos</span></label>
# <label><input name="filter_show" type="radio" value="vBForum_Video"/><span>Alleen videos</span></label>
# <label><input name="filter_show" type="radio" value="vBForum_Link"/><span>Alleen links</span></label>
# <label><input name="filter_show" type="radio" value="vBForum_Poll"/><span>Alleen enquêtes</span></label>
# <label><input name="filter_show" type="radio" value="vBForum_Event"/><span>Events only</span></label>
# </div>
# </li>
# <!-- end if prefixsets -->
# </ul>
# </form>
# <div class="filtered-by h-clearfix h-hide">
# <label>Gefilterd op:</label>
# <div class="filter-text-wrapper h-left">
# </div>
# <a class="clear-all h-hide" href="#">Clear All</a>
# </div>
# <div class="new-conversations-strip"><span></span> nieuwe berichten</div>
# </div>
# <div class="conversation-empty">Log in met je account om berichten te zien waarop je geabonneerd bent.</div>
# </div>
# <div class="" id="topic-tab">
# <div class="conversation-toolbar-wrapper top h-clear hide-on-editmode scrolltofixed-floating scrolltofixed-top " data-allow-history="1">
# <div class="conversation-toolbar js-shrink-event-parent">
# <ul class="toolset-left js-shrink-event-child ">
# <!-- new conversation button -->
# <!-- /new conversation button -->
# </ul>
# <ul class="toolset-right js-shrink-event-child">
# <li class="toolbar-pagenav js-toolbar-pagenav h-hide-on-xsmall">
# <div class="toolbar-pagenav-wrapper">
# <!-- Page Nav controls -->
# <div class="pagenav-controls ">
# <form action="https://www.hookers.nl/forum/raamprostitutie/nederland/amsterdam" class="pagenav-form h-clearfix">
# <input class="defaultpage" type="hidden" value="1"/>
# <div class="pagenav h-left">
# 			Pagina <input class="js-pagenum textbox h-padding-horiz-none" name="page" type="text" value="1"/> van <span class="pagetotal">11</span>
# </div>
# <div class="horizontal-arrows h-left">
# <a class="arrow left-arrow h-disabled" rel="prev" title="Vorige pagina"><span class="vb-icon vb-icon-arrow-left"></span></a>
# <a class="arrow right-arrow " data-orig-href="https://www.hookers.nl/forum/raamprostitutie/nederland/amsterdam/page2" data-page="2" href="https://www.hookers.nl/forum/raamprostitutie/nederland/amsterdam/page2" rel="next" title="Volgende pagina"><span class="vb-icon vb-icon-arrow-right"></span></a>
# </div>
# </form>
# </div>
# </div>
# </li>
# <li class="h-hide-on-xsmall">
# <div class="toolbar-divider">
# <span class="toolbar-divider-inner"></span>
# </div>
# </li>
# <li class="toolbar-filter toolbar-filter-top">
# <div class="filter-wrapper h-clearfix js-button" tabindex="0">
# <div class="label h-left">Filter</div>
# <div class="arrow vb-icon-wrapper h-left"><span class="vb-icon vb-icon-triangle-down-wide"></span></div>
# </div>
# </li>
# </ul>
# </div>
# <form action="activity/get" class="toolbar-filter-overlay h-clearfix" method="post">
# <input name="nodeid" type="hidden" value="85"/>
# <input name="view" type="hidden" value="topic"/>
# <input name="nolimit" type="hidden" value="1"/>
# <input name="depth" type="hidden" value="1"/>
# <input name="depth_exact" type="hidden" value="1"/>
# <input name="view" type="hidden" value="topic"/>
# <input name="per-page" type="hidden" value="50"/>
# <input name="pagenum" type="hidden" value="1"/>
# <input name="maxpages" type="hidden" value="0"/>
# <input name="userid" type="hidden" value="0"/>
# <input name="showChannelInfo" type="hidden" value="1"/>
# <ul class="filter-options-list">
# <li>
# <div class="filter-header">Tijd</div>
# <div class="filter-options">
# <label><input checked="checked" class="js-default-checked" name="filter_time" type="radio" value="time_all"/><span>Alle tijden</span></label>
# <label><input name="filter_time" type="radio" value="time_today"/><span>Vandaag</span></label>
# <label><input name="filter_time" type="radio" value="time_lastweek"/><span>Afgelopen week</span></label>
# <label><input name="filter_time" type="radio" value="time_lastmonth"/><span>Afgelopen maand</span></label>
# </div>
# </li>
# <li>
# <div class="filter-header">Toon</div>
# <div class="filter-options">
# <label><input checked="checked" class="js-default-checked" name="filter_show" type="radio" value="show_all"/><span>Alle</span></label>
# <label><input name="filter_show" type="radio" value="vBForum_Text"/><span>Alleen discussies</span></label>
# <label><input name="filter_show" type="radio" value="vBForum_Gallery"/><span>Alleen fotos</span></label>
# <label><input name="filter_show" type="radio" value="vBForum_Video"/><span>Alleen videos</span></label>
# <label><input name="filter_show" type="radio" value="vBForum_Link"/><span>Alleen links</span></label>
# <label><input name="filter_show" type="radio" value="vBForum_Poll"/><span>Alleen enquêtes</span></label>
# <label><input name="filter_show" type="radio" value="vBForum_Event"/><span>Events only</span></label>
# </div>
# </li>
# <li>
# <div class="filter-header">Sorteer op</div>
# <div class="filter-options">
# <label><input checked="checked" class="js-default-checked" name="filter_sort" type="radio" value="lastcontent"/><span>Datum - laatste update</span></label>
# <label><input name="filter_sort" type="radio" value="created"/><span>Datum - post aanmaak</span></label>
# <label><input name="filter_sort" type="radio" value="replies"/><span>Reacties</span></label>
# <label><input name="filter_sort" type="radio" value="title"/><span>Onderwerp</span></label>
# <label><input name="filter_sort" type="radio" value="author"/><span>Leden</span></label>
# <label><input name="filter_sort" type="radio" value="votes"/><span>Likes</span></label>
# </div>
# </li>
# <li>
# <div class="filter-header">Volgorde</div>
# <div class="filter-options">
# <label><input checked="checked" class="js-default-checked" name="filter_order" type="radio" value="desc"/><span>Aflopend</span></label>
# <label><input name="filter_order" type="radio" value="asc"/><span>Oplopend</span></label>
# </div>
# </li>
# <!-- end if prefixsets -->
# </ul>
# </form>
# <div class="filtered-by h-clearfix h-hide">
# <label>Gefilterd op:</label>
# <div class="filter-text-wrapper h-left">
# </div>
# <a class="clear-all h-hide" href="#">Clear All</a>
# </div>
# <div class="new-conversations-strip"><span></span> nieuwe berichten</div>
# </div>
# <div class="h-show-on-xsmall h-right h-margin-top-l js-under-toolbar-pagenav h-margin-bottom-m">
# <div class="pagenav-container h-clearfix noselect pagenav-container--no-margin">
# <div class="js-pagenav pagenav h-right js-shrink-event-parent">
# <a class="js-pagenav-button js-pagenav-prev-button b-button b-button--secondary h-hide-imp js-shrink-event-child" data-page="0" href="" tabindex="0">Vorige</a>
# <a class="js-pagenav-button b-button b-button--narrow js-shrink-event-child b-button--primary page js-pagenav-current-button js-pagenav-first-button" data-page="1" href="https://www.hookers.nl/forum/raamprostitutie/nederland/amsterdam" tabindex="0">1</a>
# <a class="js-pagenav-button b-button b-button--narrow js-shrink-event-child b-button--secondary" data-page="2" href="https://www.hookers.nl/forum/raamprostitutie/nederland/amsterdam/page2" tabindex="0">2</a>
# <a class="js-pagenav-button b-button b-button--narrow js-shrink-event-child b-button--secondary" data-page="3" href="https://www.hookers.nl/forum/raamprostitutie/nederland/amsterdam/page3" tabindex="0">3</a>
# <a class="js-pagenav-button b-button b-button--narrow js-shrink-event-child b-button--secondary" data-page="4" href="https://www.hookers.nl/forum/raamprostitutie/nederland/amsterdam/page4" tabindex="0">4</a>
# <a class="js-pagenav-button b-button b-button--narrow js-shrink-event-child b-button--secondary" data-page="5" href="https://www.hookers.nl/forum/raamprostitutie/nederland/amsterdam/page5" tabindex="0">5</a>
# <a class="js-pagenav-button b-button b-button--narrow js-shrink-event-child b-button--secondary" data-page="6" href="https://www.hookers.nl/forum/raamprostitutie/nederland/amsterdam/page6" tabindex="0">6</a>
# <a class="js-pagenav-button b-button b-button--narrow js-shrink-event-child b-button--secondary js-pagenav-last-button" data-page="11" href="https://www.hookers.nl/forum/raamprostitutie/nederland/amsterdam/page11" tabindex="0">11</a>
# <a class="js-pagenav-button js-pagenav-next-button b-button b-button--secondary js-shrink-event-child" data-page="2" href="https://www.hookers.nl/forum/raamprostitutie/nederland/amsterdam/page2" tabindex="0">Volgende</a>
# </div>
# </div>
# </div>
# <table class="topic-list-container conversation-list">
# <thead class="topic-list-header h-hide-on-xsmall js-subtoolbar-list-header">
# <tr>
# <th class="header-topic"><span>Topics</span></th>
# <th class="header-icons"></th>
# <th class="header-stats"><span>Statistieken</span></th>
# <th class="header-lastpost"><span>Laatste bericht</span></th>
# </tr>
# </thead>
# <tbody class="topic-list h-clear sticky-list">
# <tr class="topic-item sticky hasprefix im-attach js-topic-item " data-can-edit-title="0" data-channel-id="85" data-channelreadtime="" data-lastcontent="1539006627" data-node-id="10512" data-readtime="1538822635">
# <td class="cell-topic js-cell-topic">
# <div class="topic-avatar h-hide-on-large h-hide-on-wide-column">
# <a class="avatar h-left" href="https://www.hookers.nl/member/1-hkrs-admin">
# <img alt="HKRS-admin" src="./core/image.php?userid=1&amp;thumb=1&amp;dateline=1387530588" title="HKRS-admin"/>
# </a>
# </div>
# <span class="vb-icon vb-icon-topic-status js-open-close-topic h-hide-on-small h-hide-on-narrow-column" title=""></span>
# <div class="topic-wrapper js-topic-wrapper h-wordwrap">
# <span class="prefix js-prefix">Sticky: </span>
# <img alt="" class="js-post-icon h-align-top" height="16" src="https://www.hookers.nl/core/images/icons/icon4.png" width="16"/>
# <a class="topic-title js-topic-title" href="https://www.hookers.nl/forum/raamprostitutie/nederland/amsterdam/10512-amsterdam-algemeen">Amsterdam Algemeen</a>
# <span class="h-hide-on-large h-hide-on-wide-column">
#
#
# 							door <a href="https://www.hookers.nl/member/1-hkrs-admin" rel="nofollow">HKRS-admin</a>
# </span>
# <img src="/core/packages/hookersplugin/images/feet/blue6.gif"/>
# </div>
# <div class="topic-info h-clear h-hide-on-small h-hide-on-narrow-column">
#
#
#
#
# 					Gestart door <a href="https://www.hookers.nl/member/1-hkrs-admin">HKRS-admin</a>, <span class="date">23-10-06, 13:23</span>
# </div>
# </td>
# <td class="cell-icons">
# <span class="vb-icon vb-icon-attach" title="2 Bijlage(n)"></span>
# </td>
# <td class="cell-count">
# <div class="posts-count">1.812 reacties</div>
# <div class="views-count">904.348 views</div>
# <div class="votes-count">0 likes</div>
# </td>
# <td class="cell-lastpost">
# <span class="h-hide-on-large h-hide-on-wide-column">Laatste bericht</span>
# <a class="avatar h-left" href="https://www.hookers.nl/member/136859-ed-nilson">
# <img alt="ed nilson" src="./core/images/default/default_avatar_thumb.png" title="ed nilson"/>
# </a>
# <div class="lastpost-by">
#
# 								door <a href="https://www.hookers.nl/member/136859-ed-nilson" rel="nofollow">ed nilson</a>
# </div>
# <span class="post-date">08-10-18, 15:50</span>
# <a class="go-to-last-post" href="https://www.hookers.nl/forum/raamprostitutie/nederland/amsterdam/10512-amsterdam-algemeen?p=2013745" title="Ga naar laatste bericht"> </a>
# </td>
# </tr>
# <tr class="topic-item read sticky hasprefix js-topic-item " data-can-edit-title="0" data-channel-id="85" data-channelreadtime="" data-lastcontent="1535554808" data-node-id="46948" data-readtime="1538822635">
# <td class="cell-topic js-cell-topic">
# <div class="topic-avatar h-hide-on-large h-hide-on-wide-column">
# <a class="avatar h-left" href="https://www.hookers.nl/member/25293-oldamsterdam">
# <img alt="OldAmsterdam" src="./core/image.php?userid=25293&amp;thumb=1&amp;dateline=1512154962" title="OldAmsterdam"/>
# </a>
# </div>
# <span class="vb-icon vb-icon-topic-status js-open-close-topic h-hide-on-small h-hide-on-narrow-column" title=""></span>
# <div class="topic-wrapper js-topic-wrapper h-wordwrap">
# <span class="prefix js-prefix">Sticky: </span>
# <img alt="" class="js-post-icon h-align-top" height="16" src="https://www.hookers.nl/core/images/aria/icons/icon4.gif" width="16"/>
# <a class="topic-title js-topic-title" href="https://www.hookers.nl/forum/raamprostitutie/nederland/amsterdam/46948-info-kaartjes-en-adressen-amsterdam">Info, kaartjes en adressen Amsterdam</a>
# <span class="h-hide-on-large h-hide-on-wide-column">
#
#
# 							door <a href="https://www.hookers.nl/member/25293-oldamsterdam" rel="nofollow">OldAmsterdam</a>
# </span>
# </div>
# <div class="topic-info h-clear h-hide-on-small h-hide-on-narrow-column">
#
#
#
#
# 					Gestart door <a href="https://www.hookers.nl/member/25293-oldamsterdam">OldAmsterdam</a>, <span class="date">17-04-13, 08:48</span>
# </div>
# </td>
# <td class="cell-icons">
# </td>
# <td class="cell-count">
# <div class="posts-count">4 reacties</div>
# <div class="views-count">187.297 views</div>
# <div class="votes-count">0 likes</div>
# </td>
# <td class="cell-lastpost">
# <span class="h-hide-on-large h-hide-on-wide-column">Laatste bericht</span>
# <a class="avatar h-left" href="https://www.hookers.nl/member/10192-dutchlover_asd">
# <img alt="dutchlover_asd" src="./core/images/avatars/sex2/20195.gif" title="dutchlover_asd"/>
# </a>
# <div class="lastpost-by">
#
# 								door <a href="https://www.hookers.nl/member/10192-dutchlover_asd" rel="nofollow">dutchlover_asd</a>
# </div>
# <span class="post-date">29-08-18, 17:00</span>
# <a class="go-to-last-post" href="https://www.hookers.nl/forum/raamprostitutie/nederland/amsterdam/46948-info-kaartjes-en-adressen-amsterdam?p=1993992" title="Ga naar laatste bericht"> </a>
# </td>
# </tr>
# </tbody>
# <tbody class="topic-list h-clear ">
# <tr class="topic-item js-topic-item " data-can-edit-title="0" data-channel-id="85" data-channelreadtime="" data-lastcontent="1539685956" data-node-id="86526" data-readtime="1538822635">
# <td class="cell-topic js-cell-topic">
# <div class="topic-avatar h-hide-on-large h-hide-on-wide-column">
# <a class="avatar h-left" href="https://www.hookers.nl/member/35441-12inch">
# <img alt="12inch" src="./core/images/default/default_avatar_thumb.png" title="12inch"/>
# </a>
# </div>
# <span class="vb-icon vb-icon-topic-status js-open-close-topic h-hide-on-small h-hide-on-narrow-column" title=""></span>
# <div class="topic-wrapper js-topic-wrapper h-wordwrap">
# <img alt="" class="js-post-icon h-align-top" height="16" src="https://www.hookers.nl/core/images/aria/icons/icon14.gif" width="16"/>
# <a class="topic-title js-topic-title" href="https://www.hookers.nl/forum/raamprostitutie/nederland/amsterdam/86526-iryna-letl-amsterdam-singelgebied-spuistraat-24-bov-rts">Iryna (Letl), Amsterdam - Singelgebied, Spuistraat 24 bov rts</a>
# <span class="h-hide-on-large h-hide-on-wide-column">
#
#
# 							door <a href="https://www.hookers.nl/member/35441-12inch" rel="nofollow">12inch</a>
# </span>
# <img src="/core/packages/hookersplugin/images/feet/blue8.gif"/>
# </div>
# <div class="topic-info h-clear h-hide-on-small h-hide-on-narrow-column">
#
#
#
#
# 					Gestart door <a href="https://www.hookers.nl/member/35441-12inch">12inch</a>, <span class="date">04-06-17, 16:31</span>
# </div>
# </td>
# <td class="cell-icons">
# </td>
# <td class="cell-count">
# <div class="posts-count">50 reacties</div>
# <div class="views-count">17.537 views</div>
# <div class="votes-count">1 like</div>
# </td>
# <td class="cell-lastpost">
# <span class="h-hide-on-large h-hide-on-wide-column">Laatste bericht</span>
# <a class="avatar h-left" href="https://www.hookers.nl/member/296997-freekbor60">
# <img alt="freekbor60" src="./core/image.php?userid=296997&amp;thumb=1&amp;dateline=1500890308" title="freekbor60"/>
# </a>
# <div class="lastpost-by">
#
# 								door <a href="https://www.hookers.nl/member/296997-freekbor60" rel="nofollow">freekbor60</a>
# </div>
# <span class="post-date">16-10-18, 12:32</span>
# <a class="go-to-last-post" href="https://www.hookers.nl/forum/raamprostitutie/nederland/amsterdam/86526-iryna-letl-amsterdam-singelgebied-spuistraat-24-bov-rts?p=2017632" title="Ga naar laatste bericht"> </a>
# </td>
# </tr>
# <tr class="topic-item js-topic-item " data-can-edit-title="0" data-channel-id="85" data-channelreadtime="" data-lastcontent="1539630493" data-node-id="44092" data-readtime="1538822635">
# <td class="cell-topic js-cell-topic">
# <div class="topic-avatar h-hide-on-large h-hide-on-wide-column">
# <a class="avatar h-left" href="https://www.hookers.nl/member/55715-smallguy">
# <img alt="smallguy" src="./core/images/default/default_avatar_thumb.png" title="smallguy"/>
# </a>
# </div>
# <span class="vb-icon vb-icon-topic-status js-open-close-topic h-hide-on-small h-hide-on-narrow-column" title=""></span>
# <div class="topic-wrapper js-topic-wrapper h-wordwrap">
# <img alt="" class="js-post-icon h-align-top" height="16" src="https://www.hookers.nl/core/images/aria/icons/icon14.gif" width="16"/>
# <a class="topic-title js-topic-title" href="https://www.hookers.nl/forum/raamprostitutie/nederland/amsterdam/44092-sofie-ned-amsterdam-de-pijp-ruysdaelkade-121-mid">Sofie (Ned), Amsterdam - De Pijp, Ruysdaelkade 121 mid</a>
# <span class="h-hide-on-large h-hide-on-wide-column">
#
#
# ...
# <a class="topic-title js-topic-title" href="https://www.hookers.nl/forum/raamprostitutie/nederland/amsterdam/2008226-anna-ukr-amsterdam-de-wallen-gordijnensteeg-4-5">Anna (Ukr), Amsterdam - De Wallen, Gordijnensteeg 4-5</a>
# <span class="h-hide-on-large h-hide-on-wide-column">
#
#
# 							door <a href="https://www.hookers.nl/member/251430-jake-roberts" rel="nofollow">Jake Roberts</a>
# </span>
# <img src="/core/packages/hookersplugin/images/feet/blue7.gif"/>
# </div>
# <div class="topic-info h-clear h-hide-on-small h-hide-on-narrow-column">
#
#
#
#
# 					Gestart door <a href="https://www.hookers.nl/member/251430-jake-roberts">Jake Roberts</a>, <span class="date">26-09-18, 22:36</span>
# </div>
# </td>
# <td class="cell-icons">
# </td>
# <td class="cell-count">
# <div class="posts-count">0 reacties</div>
# <div class="views-count">284 views</div>
# <div class="votes-count">0 likes</div>
# </td>
# <td class="cell-lastpost">
# <span class="h-hide-on-large h-hide-on-wide-column">Laatste bericht</span>
# <a class="avatar h-left" href="https://www.hookers.nl/member/251430-jake-roberts">
# <img alt="Jake Roberts" src="./core/image.php?userid=251430&amp;thumb=1&amp;dateline=1503001287" title="Jake Roberts"/>
# </a>
# <div class="lastpost-by">
#
# 								door <a href="https://www.hookers.nl/member/251430-jake-roberts" rel="nofollow">Jake Roberts</a>
# </div>
# <span class="post-date">26-09-18, 22:36</span>
# <a class="go-to-last-post" href="https://www.hookers.nl/forum/raamprostitutie/nederland/amsterdam/2008226-anna-ukr-amsterdam-de-wallen-gordijnensteeg-4-5?p=2008226" title="Ga naar laatste bericht"> </a>
# </td>
# </tr>
# <tr class="topic-item read js-topic-item " data-can-edit-title="0" data-channel-id="85" data-channelreadtime="" data-lastcontent="1537977924" data-node-id="1853721" data-readtime="1538822635">
# <td class="cell-topic js-cell-topic">
# <div class="topic-avatar h-hide-on-large h-hide-on-wide-column">
# <a class="avatar h-left" href="https://www.hookers.nl/member/335870-ronbreda">
# <img alt="ronbreda" src="./core/image.php?userid=335870&amp;thumb=1&amp;dateline=1509700488" title="ronbreda"/>
# </a>
# </div>
# <span class="vb-icon vb-icon-topic-status js-open-close-topic h-hide-on-small h-hide-on-narrow-column" title=""></span>
# <div class="topic-wrapper js-topic-wrapper h-wordwrap">
# <img alt="" class="js-post-icon h-align-top" height="16" src="https://www.hookers.nl/core/images/aria/icons/icon7.gif" width="16"/>
# <a class="topic-title js-topic-title" href="https://www.hookers.nl/forum/raamprostitutie/nederland/amsterdam/1853721-claudia-lat-amsterdam-de-wallen-boomsteeg-1a">Claudia (Lat), Amsterdam - De Wallen, Boomsteeg 1b</a>
# <span class="h-hide-on-large h-hide-on-wide-column">
#
#
# 							door <a href="https://www.hookers.nl/member/335870-ronbreda" rel="nofollow">ronbreda</a>
# </span>
# <img src="/core/packages/hookersplugin/images/feet/blue8.gif"/>
# </div>
# <div class="topic-info h-clear h-hide-on-small h-hide-on-narrow-column">
#
#
#
#
# 					Gestart door <a href="https://www.hookers.nl/member/335870-ronbreda">ronbreda</a>, <span class="date">01-11-17, 15:26</span>
# </div>
# </td>
# <td class="cell-icons">
# </td>
# <td class="cell-count">
# <div class="posts-count">9 reacties</div>
# <div class="views-count">2.548 views</div>
# <div class="votes-count">0 likes</div>
# </td>
# <td class="cell-lastpost">
# <span class="h-hide-on-large h-hide-on-wide-column">Laatste bericht</span>
# <a class="avatar h-left" href="https://www.hookers.nl/member/10907-goodbar">
# <img alt="goodbar" src="./core/image.php?userid=10907&amp;thumb=1&amp;dateline=1129122965" title="goodbar"/>
# </a>
# <div class="lastpost-by">
#
# 								door <a href="https://www.hookers.nl/member/10907-goodbar" rel="nofollow">goodbar</a>
# </div>
# <span class="post-date">26-09-18, 18:05</span>
# <a class="go-to-last-post" href="https://www.hookers.nl/forum/raamprostitutie/nederland/amsterdam/1853721-claudia-lat-amsterdam-de-wallen-boomsteeg-1a?p=2008078" title="Ga naar laatste bericht"> </a>
# </td>
# </tr>
# </tbody>
# </table>
# <div class="pagenav-container h-clearfix noselect">
# <div class="js-pagenav pagenav h-right js-shrink-event-parent">
# <a class="js-pagenav-button js-pagenav-prev-button b-button b-button--secondary h-hide-imp js-shrink-event-child" data-page="0" tabindex="0">Vorige</a>
# <a class="js-pagenav-button b-button b-button--narrow js-shrink-event-child b-button--primary page js-pagenav-current-button js-pagenav-first-button" data-page="1" tabindex="0">1</a>
# <a class="js-pagenav-button b-button b-button--narrow js-shrink-event-child b-button--secondary" data-page="2" tabindex="0">2</a>
# <a class="js-pagenav-button b-button b-button--narrow js-shrink-event-child b-button--secondary" data-page="3" tabindex="0">3</a>
# <a class="js-pagenav-button b-button b-button--narrow js-shrink-event-child b-button--secondary" data-page="4" tabindex="0">4</a>
# <a class="js-pagenav-button b-button b-button--narrow js-shrink-event-child b-button--secondary" data-page="5" tabindex="0">5</a>
# <a class="js-pagenav-button b-button b-button--narrow js-shrink-event-child b-button--secondary" data-page="6" tabindex="0">6</a>
# <a class="js-pagenav-button b-button b-button--narrow js-shrink-event-child b-button--secondary js-pagenav-last-button" data-page="11" tabindex="0">11</a>
# <a class="js-pagenav-button js-pagenav-next-button b-button b-button--secondary js-shrink-event-child" data-page="2" tabindex="0">Volgende</a>
# </div>
# </div>
# <div class="conversation-empty h-hide">Geen onderwerpen gevonden.</div>
# <div class="list-footer">
# <a class="js-markread" data-action="markRead" href="#">Markeer dit forum als gelezen</a>
# </div>
# </div>
# <div class="media-tab h-hide" id="media-tab">
# <div class="conversation-toolbar-wrapper top h-clear hide-on-editmode scrolltofixed-floating" data-allow-history="1">
# <div class="profile-toolbar conversation-toolbar js-shrink-event-parent">
# <ul class="toolset-left h-left js-shrink-event-child">
# </ul>
# <ul class="toolset-right h-right js-shrink-event-child">
# <li class="pagenav-controls-container h-hide">
# <div class="pagenav-controls h-right">
# <div class="pagenav h-left">
# 						Pagina <input class="textbox" id="mediaCurrentPage" name="mediaPage" type="text" value="0"/> van <span class="pagetotal" id="mediaPageCount">0</span>
# </div>
# <div class="horizontal-arrows h-left">
# <span class="arrow left-arrow h-disabled" id="mediaPreviousPage" title="Vorige pagina"><span class="vb-icon vb-icon-arrow-left"></span></span>
# <span class="arrow right-arrow h-disabled" id="mediaNextPage" title="Volgende pagina"><span class="vb-icon vb-icon-arrow-right"></span></span>
# </div>
# </div>
# </li>
# <li class="toolbar-filter media-toolbar-filter h-hide" id="toolbar-filter-">
# <div class="filter-wrapper h-clearfix js-button" tabindex="0">
# <div class="label h-left">Filter</div>
# <div class="arrow vb-icon-wrapper h-left"><span class="vb-icon vb-icon-triangle-down-wide"></span></div>
# </div>
# </li>
# </ul>
# </div>
# <form class="toolbar-filter-overlay media-filter-overlay h-clearfix">
# <ul class="filter-options-list">
# <li>
# <div class="filter-header">Tijd</div>
# <div class="filter-options h-left">
# <label><input name="filter_time" type="radio" value="time_all"/><span>Elke tijd</span></label>
# <label><input name="filter_time" type="radio" value="time_today"/><span>Vandaag</span></label>
# <label><input name="filter_time" type="radio" value="time_lastweek"/><span>Afgelopen week</span></label>
# <label><input checked="checked" class="js-default-checked" name="filter_time" type="radio" value="time_lastmonth"/><span>Afgelopen maand</span></label>
# </div>
# </li>
# </ul>
# </form>
# <div class="filtered-by h-clearfix h-hide">
# <label>Gefilterd op:</label>
# <div class="filter-text-wrapper h-left">
# </div>
# <a class="clear-all h-hide" href="#">Clear All</a>
# </div>
# </div>
# <div class="js-post js-slideshow__gallery-node h-hide" data-channelid="85" data-nodeid="-2" id="profileMediaDetailContainer">
# </div>
# <script type="text/javascript">
# 	window.vBulletin = window.vBulletin || {};
# 	window.vBulletin.media = window.vBulletin.media || {};
#
# 	window.vBulletin.media.TARGET_PHOTOS_PERPAGE = 35;
# 	window.vBulletin.media.ALBUMS_PERPAGE = Number("") || 15;
#
# 	window.vBulletin.media.MEDIA_USERID = "";
# </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- *** END WIDGET widgetid:6, widgetinstanceid:13, template:widget_channeldisplay *** -->
# </div>
# </div>
# <!-- row -->
# <div class="canvas-layout-row l-row no-columns h-clearfix">
# <!-- section 3 -->
# <div class="canvas-widget-list section-3 js-sectiontype-extra h-clearfix l-col__large-12 l-col__small--full l-wide-column">
# <!-- *** START WIDGET widgetid:43, widgetinstanceid:173, template:widget_ad *** -->
# <div class="b-module b-module--hide-small b-module--hide-xsmall js-module canvas-widget default-widget axd-widget axd-container" data-widget-id="43" data-widget-instance-id="173" id="widget_173">
# <div class="widget-content restore axd axd_173">
# <div class="axd-inner js-module__hide-if-empty axd-inner_centered">
# <div class="ad_173_inner"><!-- Adform publisher tag -->
# <!-- Tag for Hookers.nl - Hookers.nl_ Midden_1_300x250_btf placement -->
# <script data-adfscript="adx.adform.net/adx/?mid=433305"></script>
# <script async="" src="https://s1.adform.net/banners/scripts/adx.js"></script><!-- Adform publisher tag -->
# <!-- Tag for Hookers.nl - Hookers.nl_ Midden_2_300x250_btf placement -->
# <script data-adfscript="adx.adform.net/adx/?mid=433308"></script>
# <script async="" src="https://s1.adform.net/banners/scripts/adx.js"></script><!-- Adform publisher tag -->
# <!-- Tag for Hookers.nl - Hookers.nl_ Midden_3_300x250_btf placement -->
# <script data-adfscript="adx.adform.net/adx/?mid=433310"></script>
# <script async="" src="https://s1.adform.net/banners/scripts/adx.js"></script></div>
# </div>
# </div>
# </div>
# <!-- *** END WIDGET widgetid:43, widgetinstanceid:173, template:widget_ad *** -->
# <!-- *** START WIDGET widgetid:43, widgetinstanceid:174, template:widget_ad *** -->
# <div class="b-module b-module--hide-desktop b-module--hide-xsmall js-module canvas-widget default-widget axd-widget axd-container" data-widget-id="43" data-widget-instance-id="174" id="widget_174">
# <div class="widget-content restore axd axd_174">
# <div class="axd-inner js-module__hide-if-empty axd-inner_centered">
# <div class="ad_174_inner"><!-- Adform publisher tag -->
# <!-- Tag for Hookers.nl - Hookers.nl_ Midden_1_300x250_btf placement -->
# <script data-adfscript="adx.adform.net/adx/?mid=433305"></script>
# <script async="" src="https://s1.adform.net/banners/scripts/adx.js"></script><!-- Adform publisher tag -->
# <!-- Tag for Hookers.nl - Hookers.nl_ Midden_2_300x250_btf placement -->
# <script data-adfscript="adx.adform.net/adx/?mid=433308"></script>
# <script async="" src="https://s1.adform.net/banners/scripts/adx.js"></script></div>
# </div>
# </div>
# </div>
# <!-- *** END WIDGET widgetid:43, widgetinstanceid:174, template:widget_ad *** -->
# <!-- *** START WIDGET widgetid:43, widgetinstanceid:175, template:widget_ad *** -->
# <div class="b-module b-module--hide-desktop b-module--hide-small js-module canvas-widget default-widget axd-widget axd-container" data-widget-id="43" data-widget-instance-id="175" id="widget_175">
# <div class="widget-content restore axd axd_175">
# <div class="axd-inner js-module__hide-if-empty axd-inner_centered">
# <div class="ad_175_inner"><!-- Adform publisher tag -->
# <!-- Tag for Hookers.nl - Hookers.nl_ Midden_1_300x250_btf placement -->
# <script data-adfscript="adx.adform.net/adx/?mid=433305"></script>
# <script async="" src="https://s1.adform.net/banners/scripts/adx.js"></script></div>
# </div>
# </div>
# </div>
# <!-- *** END WIDGET widgetid:43, widgetinstanceid:175, template:widget_ad *** -->
# </div>
# </div>
# </div>
# </div>
# <div class="h-clear"></div>
# </div>
# <div id="footer">
# <div class="footer-top">
# <a class="js-footer-go-to-top" href="#"><i aria-hidden="true" class="fa fa-arrow-up"></i>Ga naar de bovenkant</a>
# </div>
# <div class="footer-content">
# <div class="list-container">
# <div class="footer-list">
# <h3>Algemeen</h3>
# <ul>
# <li><a href="/forum/hookers-hang-out/over-ons"><i aria-hidden="true" class="fa fa-angle-right"></i>Over Hookers</a></li>
# <li><a href="http://www.kinky.nl/voorwaarden.aspx"><i aria-hidden="true" class="fa fa-angle-right"></i>Algemene voorwaarden</a></li>
# <li><a href="/forum/hookers-hang-out/over-ons/regels-en-faq"><i aria-hidden="true" class="fa fa-angle-right"></i>Regels &amp; FAQ</a></li>
# </ul>
# <ul class="h-left js-footer-chooser-list h-margin-left-xxl">
# </ul>
# </div>
# <div class="footer-list">
# <h3>Service</h3>
# <ul>
# <li><a href="/help"><i aria-hidden="true" class="fa fa-angle-right"></i>Help</a></li>
# <li><a href="/contact-us"><i aria-hidden="true" class="fa fa-angle-right"></i>Contact</a></li>
# </ul>
# </div>
# <div class="footer-list">
# <h3>Meer Hookers</h3>
# <ul>
# <li><a href="mailto:sales@midholdmedia.nl"><i aria-hidden="true" class="fa fa-angle-right"></i>Adverteren</a></li>
# <li><a href="http://www.kinky.nl/veiligafspreken.aspx"><i aria-hidden="true" class="fa fa-angle-right"></i>Veilig Afspreken</a></li>
# </ul>
# </div>
# </div>
# <div class="nieuwsbrief">
# </div>
# </div>
# </div>
# </div>
# <div id="footer-copyright">
# <div id="footer-vb-copyright">Forumsoftware: vBulletin®, versie 5.3.4<br/>Copyright ©2000 - 2018, Jelsoft Enterprises Ltd.</div>
# <div id="footer-user-copyright">© 2002 - heden Hookers.nl</div>
# <div id="footer-current-datetime">Alle tijden zijn GMT+1. Deze pagina is gegenereerd op 12:43.</div>
# </div>
# </div>
# <div class="js-loading-indicator b-ajax-loading-indicator h-hide" id="loading-indicator">
# <span>Aan het werk...</span>
# </div>
# <div class="sb-dialog" id="confirm-dialog">
# <div class="dialog-content h-clearfix">
# <div class="icon h-left"></div>
# <div class="message"></div>
# </div>
# <div class="b-button-group">
# <button class="b-button b-button--primary js-button" id="btnConfirmDialogYes" type="button">Ja</button>
# <button class="b-button b-button--secondary js-button" id="btnConfirmDialogNo" type="button">Nee</button>
# </div>
# </div>
# <div class="sb-dialog" id="alert-dialog">
# <div class="dialog-content h-clearfix">
# <div class="icon h-left"></div>
# <div class="message"></div>
# </div>
# <div class="b-button-group">
# <button class="b-button b-button--primary js-button" id="btnAlertDialogOK" type="button">OK</button>
# </div>
# </div>
# <div class="sb-dialog" id="prompt-dialog">
# <div class="dialog-content table h-clearfix">
# <div class="message td"></div>
# <div class="input-box-container td">
# <input class="input-box textbox" type="text"/>
# <textarea class="input-box textbox h-hide" rows="3"></textarea>
# </div>
# </div>
# <div class="b-button-group">
# <button class="b-button b-button--primary js-button" id="btnPromptDialogOK" type="button">OK</button>
# <button class="b-button b-button--secondary js-button" id="btnPromptDialogCancel" type="button">Annuleren</button>
# </div>
# </div>
# <div class="sb-dialog slideshow" id="slideshow-dialog">
# <div class="slideshow-wrapper"><div class="vb-icon vb-icon-x-square close-btn">X</div></div>
# <div class="caption"></div>
# <div class="thumbnails"></div>
# </div>
# <div class="unsubscribe-overlay-container"></div>
# <div data-facebook-language="en_US" id="fb-root"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/2.1.4/jquery.min.js" type="text/javascript"></script>
# <script src="js/footer-rollup-534.js" type="text/javascript"></script>
# <script type="text/javascript">
#
# 		window.vBulletin = window.vBulletin || {};
# 		  (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-23433632-4', 'auto');
#   ga('send', 'pageview');
#
#
# 		vBulletin.version = '5.3.4';
# </script>
# <script src="js/inlinemod.js?v=534" type="text/javascript"></script>
# <script src="js/channel-rollup-534.js" type="text/javascript"></script>
# </body>
# </html>
