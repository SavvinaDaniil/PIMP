# %%
from urllib.request import urlopen

hookers_nl = "https://www.hookers.nl/forum/raamprostitutie/nederland/amsterdam"

f = urlopen(hookers_nl)
myfile = f.read()

# %%
from bs4 import BeautifulSoup
from json import loads

soup = BeautifulSoup(myfile)
text = soup.get_text()

#find the values describing the reviews
json_alphabetic = soup.findAll('alphabetic')[0]

#extract the dict from the :topics attribute and delete string. 
dict_hookers = loads(json_alphabetic.attrs[':topics'][14:-1])
# Out:
# C:\Users\brech\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\brech\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
import pandas as pd
df_hookers = pd.DataFrame(list(dict_hookers.values()))
df_hookers
# Out:
#                          city company                   name   nodeid  \
# 0       Amsterdam - De Wallen    None                 Anna 1      259
# 1                      Wallen    None                 Stella      260
# 2                Singelgebied    None            Laura (Ned)      262
# 3       Amsterdam - De Wallen    None                Sherida      288
# 4                      Wallen    None         Sandy (Filipp)      299
# 5                Singelgebied    None           Mirjam (Sur)      324
# 6                Singelgebied    None           Tamara (Ned)      393
# 7                Singelgebied    None          Marina (Oekr)      432
# 8    Amsterdam - Singelgebied    None           Carmen (Lat)      558
# 9                      Wallen    None               Jennifer      571
# 10               Singelgebied    None             Sara (Lat)      581
# 11               Singelgebied    None                Claudia      603
# 12                    De Pijp    None                 Judith      615
# 13        Amsterdam - De Pijp    None     Patricia (Dom R)        667
# 14                    De Pijp    None       Gloria (Claudia)      670
# 15                     Wallen    None          Gloria (Albn)      707
# 16               Singelgebied    None         Nathalie (Lat)      749
# 17                     Wallen    None           Sylvia (Ned)      982
# 18                    De Pijp    None                  Sonja      984
# 19               Singelgebied    None        Maris (Marisol)      998
# 20                     Wallen    None            Anna (Ital)     1088
# 21                     Wallen    None  Sofia / Emilia (Roem)     1143
# 22                     Wallen    None                  Maria     1224
# 23                     Wallen    None              Angelique     1334
# 24   Amsterdam - Singelgebied    None               Kristina     1351
# 25               Singelgebied    None           Eva (Tsjech)     1381
# 26                     Wallen    None           Marie (Peru)     1467
# 27                     Wallen    None         Melanie (Thai)     1786
# 28      Amsterdam - De Wallen    None              Agnieszka     1821
# 29               Singelgebied    None                 Gloria     1915
# ..                        ...     ...                    ...      ...
# 493       Amsterdam - De Pijp    None            Katja (Pol)  1946802
# 494     Amsterdam - De Wallen    None            Kaira (Rus)  1946962
# 495     Amsterdam - De Wallen    None          Sandra (Roem)  1958414
# 496     Amsterdam - De Wallen    None                  Elina  1963252
# 497       Amsterdam - De Pijp    None                Larissa  1963820
# 498     Amsterdam - De Wallen    None          Joleina (Tsj)  1965887
# 499       Amsterdam - De Pijp    None                Jessica  1967866
# 500       Amsterdam - De Pijp    None           Briana (Ita)  1967872
# 501     Amsterdam - De Wallen    None       Isabel (Dom R.)   1972060
# 502     Amsterdam - De Wallen    None           Penka (Bulg)  1974364
# 503     Amsterdam - De Wallen    None                   Cora  1981749
# 504     Amsterdam - De Wallen    None          Ariane (Roem)  1981918
# 505     Amsterdam - De Wallen    None           Anaïs (Roem)  1983518
# 506     Amsterdam - De Wallen    None             Hera (Rus)  1991722
# 507     Amsterdam - De Wallen    None                 Helena  1992779
# 508       Amsterdam - De Pijp    None         Lorena (Mold)   1996927
# 509     Amsterdam - De Wallen    None              Mia (Tsj)  1998031
# 510     Amsterdam - De Wallen    None            Daria (Rus)  1998913
# 511     Amsterdam - De Wallen    None          Elena (O E)    1999447
# 512     Amsterdam - De Wallen    None          Sophia (Roem)  2000130
# 513     Amsterdam - De Wallen    None           Pamela (Alb)  2002884
# 514                      None    None                   None  2005372
# 515  Amsterdam - Singelgebied    None            Helen (O E)  2007389
# 516     Amsterdam - De Wallen    None             Anna (Ukr)  2008226
# 517  Amsterdam - Singelgebied    None          Denisa (Roem)  2010577
# 518     Amsterdam - De Wallen    None         Natasja (Bulg)  2010738
# 519       Amsterdam - De Pijp    None             Michelle 2  2010795
# 520  Amsterdam - Singelgebied    None               Victoria  2012273
# 521       Amsterdam - De Pijp    None             Lola (Lat)  2016390
# 522       Amsterdam - De Pijp    None            Sarah (Grk)  2016880
#
#           number    score                   street
# 0             k8   9.0088           La Vie en Rose
# 1    68 sous rts   7.5893  Oudezijds Achterburgwal
# 2          3 rts   8.4211          Korte Kolksteeg
# 3            1-2   6.1250          Trompettersteeg
# 4          4 lks   8.6087               Stoofsteeg
# 5          6 bov   8.0667         Oude Nieuwstraat
# 6             7a   8.9048  Korte Korsjespoortsteeg
# 7            41a   8.4889                   Singel
# 8          2 lks   6.5152         Oude Nieuwstraat
# 9          9 lks   9.2162               Stoofsteeg
# 10          None   8.5000         Oude Nieuwstraat
# 11    19 bov lks   6.8125               Spuistraat
# 12             1   8.6333      Govert Flinckstraat
# 13       135 lks   8.2174             Ruysdaelkade
# 14           201   8.4032             Ruysdaelkade
# 15           5-6   6.4314          Trompettersteeg
# 16        47 lks   7.9583               Spuistraat
# 17         4 mid   8.3793               Stoofsteeg
# 18   141 ben lks   8.3934             Ruysdaelkade
# 19         4 mid   7.7609         Oude Nieuwstraat
# 20          51-4   8.3333  Oudezijds Achterburgwal
# 21           7-3   8.8043       Dollebegijnensteeg
# 22        34 lks   8.3662           Oudekerksplein
# 23           119   8.7200         Sint Annenstraat
# 24         3 lks   8.3372          Korte Kolksteeg
# 25         4 mid   8.7647         Oude Nieuwstraat
# 26          111a   6.2381       Dollebegijnensteeg
# 27         5 lks   8.8485          Oudekennissteeg
# 28        72 rts   8.6786  Oudezijds Achterburgwal
# 29        24 bov   8.3803         Oude Nieuwstraat
# ..           ...      ...                      ...
# 493    129 /hoek  10.0000             Ruysdaelkade
# 494         11-2  10.0000  Oudezijds Achterburgwal
# 495           k6   5.0000           La Vie en Rose
# 496           k2   2.0000           La Vie en Rose
# 497      127 lks   8.0000             Ruysdaelkade
# 498          1-3   7.8333    Sint Annendwarsstraat
# 499      119 lks   8.0000             Ruysdaelkade
# 500      119 rts   7.5000             Ruysdaelkade
# 501          6-2   9.0000               Molensteeg
# 502          4-1  10.0000               Molensteeg
# 503           k8   9.3333           La Vie en Rose
# 504        2 mid   6.0000          Oudekennissteeg
# 505          7-5  10.0000       Dollebegijnensteeg
# 506          6-2   9.3333               Molensteeg
# 507   89 bov lks   9.0000  Oudezijds Achterburgwal
# 508      137 lks   6.5455             Ruysdaelkade
# 509         59-7   8.5000           Monnikenstraat
# 510           11   8.0000             Bethlemsteeg
# 511          9-1  10.0000               Molensteeg
# 512         None  10.0000               Molensteeg
# 513       13 lks   8.0000  Oudezijds Achterburgwal
# 514         None   7.2500                     None
# 515  24 sous rts   6.6667               Spuistraat
# 516          4-5   7.3333           Gordijnensteeg
# 517            6  10.0000          Korte Kolksteeg
# 518         111a   9.3333       Dollebegijnensteeg
# 519      141 rts   4.6667             Ruysdaelkade
# 520           19   8.6667         Oude Nieuwstraat
# 521      201 lks   6.0000             Ruysdaelkade
# 522      141 rts   8.6667             Ruysdaelkade
#
# [523 rows x 7 columns]
